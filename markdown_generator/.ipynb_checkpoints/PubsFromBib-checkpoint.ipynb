# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "conference": {
        "file" : "conference.bib",
        "venuekey": "booktitle",
        "venue-pretext": "Proc. of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    }#,
   # "journal":{
   #     "file": "pubs.bib",
   #     "venuekey" : "journal",
   #     "venue-pretext" : "",
   #     "collection" : {"name":"publications",
   #                     "permalink":"/publication/"}
   # } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# WARNING Missing Expected Field 'inproceedings' from entry AliDalpGior2008: " Location-based Variability for ... "
# WARNING Missing Expected Field 'inproceedings' from entry AliDalpGior2008a: " Location-based Software Modeli ... "
# WARNING Missing Expected Field 'inproceedings' from entry AliDalpGior2009: " A Goal Modeling Framework for  ... "
# WARNING Missing Expected Field 'inproceedings' from entry AliDalpGior2008b: " Modeling and Analyzing Variabi ... "
# WARNING Missing Expected Field 'inproceedings' from entry AliDalpGior2011: " Requirements Evolution: From A ... "
# WARNING Missing Expected Field 'inproceedings' from entry AliGrigFran2012: " Optimizing Monitoring Requirem ... "
# WARNING Missing Expected Field 'inproceedings' from entry BrylDalpFerr2007: " Evaluating Procedural Alternat ... "
# WARNING Missing Expected Field 'inproceedings' from entry ChopDalpGior2010: " Reasoning about Agents and Pro ... "
# WARNING Missing Expected Field 'inproceedings' from entry ChopDalpGior2010a: " Modeling and Reasoning about S ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpAliGior2012: " Aligning Software Configuratio ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpChopGior2010: " Adaptation in Open Systems: Gi ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpGiorMylo2009: " An Architecture for Requiremen ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpGiorMylo2009a: " Software Self-Reconfiguration: ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpSerrVald2012: " {A NFR-based} Framework for Us ... "
# WARNING Missing Expected Field 'inproceedings' from entry FranDalpMylo2013: " {TBIM}: A Language for Modelin ... "
# WARNING Missing Expected Field 'inproceedings' from entry PajaDalpGior2013a: " Managing Security Requirements ... "
# WARNING Missing Expected Field 'inproceedings' from entry SalnDalpGior2012: " Aligning Service-Oriented Arch ... "
# WARNING Missing Expected Field 'inproceedings' from entry ShvaMionDalp2010: " {The TasLab portal for collabo ... "
# WARNING Missing Expected Field 'inproceedings' from entry VaraAliDalp2010: " Business Process Contextualisa ... "
# WARNING Missing Expected Field 'inproceedings' from entry VaraAliDalp2010a: " {COMPRO}: A Methodological App ... "
# WARNING Missing Expected Field 'inproceedings' from entry VlaaDalpBrin2014: " Finding Optimal Plans for Incr ... "
# WARNING Missing Expected Field 'inproceedings' from entry SalnDalpGior2014: " Modeling and Verifying Securit ... "
# WARNING Missing Expected Field 'inproceedings' from entry AydeDalpGiorMylo2014: " Exploring Alternative Designs  ... "
# WARNING Missing Expected Field 'inproceedings' from entry ChopDalpAydeGior2014: " {Protos}: Foundations for Engi ... "
# WARNING Missing Expected Field 'inproceedings' from entry AarnPeurDalp2014: " The Evolution of Advergames De ... "
# WARNING Missing Expected Field 'inproceedings' from entry HossShahPhal2015: " Configuring Crowdsourcing for  ... "
# WARNING Missing Expected Field 'inproceedings' from entry FranDalpMylo2015: " Modeling Strategic Business Pl ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpCardCano2015: " Social Specifications of Busin ... "
# WARNING Missing Expected Field 'inproceedings' from entry HelmDalpBarn2015: " A Method for the Design of Gam ... "
# WARNING Missing Expected Field 'inproceedings' from entry LucaDalpWerf2015b: " Forging High-Quality User Stor ... "
# WARNING Missing Expected Field 'inproceedings' from entry SernDalpDrag2015: " {Smart Tales}: An Awareness Ga ... "
# WARNING Missing Expected Field 'inproceedings' from entry RounDalp2015: " A Model-driven Framework for E ... "
# WARNING Missing Expected Field 'inproceedings' from entry LucaDalpWerfBrin2016a: " The Use and Effectiveness of U ... "
# WARNING Missing Expected Field 'inproceedings' from entry StriDalpBate2016: " Designing a Serious Game for G ... "
# WARNING Missing Expected Field 'inproceedings' from entry RobeLucaWerfDalpBrin2016: " Automated Extraction of Concep ... "
# WARNING Missing Expected Field 'inproceedings' from entry CardLabuDalpMyloGior2016: " Modeling Structured and Unstru ... "
# WARNING Missing Expected Field 'inproceedings' from entry LucaDalpWerfBrin2016b: " Visualizing User Story Require ... "
# WARNING Missing Expected Field 'inproceedings' from entry LucaDalpWerfBrin2017: " Improving User Story Practice  ... "
# WARNING Missing Expected Field 'inproceedings' from entry SernDalpDrag2017: " Contextual Requirements Priori ... "
# WARNING Missing Expected Field 'inproceedings' from entry AlamDalp2017: " A Gamified Tutorial for Learni ... "
# WARNING Missing Expected Field 'inproceedings' from entry LombDalpLucaBrin2016: " Gamified Requirements Engineer ... "
# WARNING Missing Expected Field 'inproceedings' from entry LucaKeukDalpBrin18: " Jobs-to-be-Done Oriented Requi ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpSchaLuca18: " Pinpointing Ambiguity and Inco ... "
# WARNING Missing Expected Field 'inproceedings' from entry AydeDalpBrinGior2018: " The Next Release Problem Revis ... "
# WARNING Missing Expected Field 'inproceedings' from entry DellDastDalp2018: " {Runtime Norm Revision using B ... "
# WARNING Missing Expected Field 'inproceedings' from entry MuteDeosMathBrinDalp2019: " Refinement of User Stories int ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpPare2019: " {RE-SWOT}: From User Feedback  ... "
# WARNING Missing Expected Field 'inproceedings' from entry DellDastDalp2019: " Runtime Revision of Norms and  ... "
# WARNING Missing Expected Field 'inproceedings' from entry DeleDalpCoop2019: " {BakeRE}: A Serious Educationa ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpDellAydeCevi2019: " Requirements Classification wi ... "
# WARNING Missing Expected Field 'inproceedings' from entry VlieGroeDalpBrin2020: " Identifying and Classifying Us ... "
# WARNING Missing Expected Field 'inproceedings' from entry MoleSpijDalpBrin2020: " Explicit Alignment of Requirem ... "
# WARNING Missing Expected Field 'inproceedings' from entry DalpStur2020: " Conceptualizing Requirements U ... "
# WARNING Missing Expected Field 'inproceedings' from entry Maas2020: " The {Care2Report} System: Auto ... "
# WARNING Missing Expected Field 'inproceedings' from entry AydeDalp2020: " Supporting Collaborative Model ... "
# WARNING Missing Expected Field 'inproceedings' from entry SpijDalpBrin2021: " Requirements Elicitation via F ... "
# WARNING Missing Expected Field 'inproceedings' from entry Wouters2021: " {CrowdRE} in a Governmental Se ... "
# WARNING Missing Expected Field 'inproceedings' from entry Berends2021: " Refining User Stories via Exam ... "
# WARNING Missing Expected Field 'inproceedings' from entry BragDalpStur2022: " Guided Derivation of Conceptua ... "
# WARNING Missing Expected Field 'inproceedings' from entry RasiDalpEspa2022: " How Effective Is Automated Tra ... "
# WARNING Missing Expected Field 'inproceedings' from entry ElAsDeVeDalpBri2022: " A Semi-automated Method for Do ... "
# WARNING Missing Expected Field 'inproceedings' from entry MoleSteevdBeDalpBrin2022: " Defining Key Concepts in Infor ... "
# WARNING Missing Expected Field 'inproceedings' from entry SpijDalpBrin2022: " Back to the Roots: Linking Use ... "
# WARNING Missing Expected Field 'inproceedings' from entry SpijBondDalpBrin2023: " Summarization of Elicitation C ... "
# WARNING Missing Expected Field 'inproceedings' from entry vanCDalp2024: " Requirements Information in Ba ... "
# WARNING Missing Expected Field 'inproceedings' from entry BragVanCDalpStur2024: " Deriving Domain Models from Us ... "
